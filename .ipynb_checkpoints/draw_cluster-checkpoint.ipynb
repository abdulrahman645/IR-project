# %%
from storge.storge import load_binary_file

# %%
model = load_binary_file('wikiren1ktraining','model')
speras_matrix = load_binary_file('wikiren1ktraining','speras_matrix_docs')

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import TruncatedSVD

svd = TruncatedSVD(n_components=2, random_state=0)
reduced_features = svd.fit_transform(speras_matrix)  # No need to call toarray()

reduced_cluster_centers = svd.transform(model.cluster_centers_)

plt.scatter(reduced_features[:,0], reduced_features[:,1], c=model.predict(speras_matrix))
plt.scatter(reduced_cluster_centers[:, 0], reduced_cluster_centers[:,1], marker='x', s=150, c='b')

plt.show()

# %%
model = load_binary_file('antiquetrain','model')
speras_matrix = load_binary_file('antiquetrain','speras_matrix_docs')

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import TruncatedSVD

svd = TruncatedSVD(n_components=2, random_state=0)
reduced_features = svd.fit_transform(speras_matrix)  # No need to call toarray()

reduced_cluster_centers = svd.transform(model.cluster_centers_)

plt.scatter(reduced_features[:,0], reduced_features[:,1], c=model.predict(speras_matrix))
plt.scatter(reduced_cluster_centers[:, 0], reduced_cluster_centers[:,1], marker='x', s=150, c='b')

plt.show()
